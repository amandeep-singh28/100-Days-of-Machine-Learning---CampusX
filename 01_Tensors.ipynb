# %% [markdown]
# #### 0D Tensors/ Scalar

# %%
import numpy as np

# %%
a = np.array(0)

# %%
a
# Out:
# array(0)

# %%
a.ndim
# Out:
# 0

# %%
arr = np.array([1, 2, 3, 4])

# %%
arr
# Out:
# array([1, 2, 3, 4])

# %%
arr.ndim
# Out:
# 1
