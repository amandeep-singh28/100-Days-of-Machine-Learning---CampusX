# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "the movie is good",
    "the movie is bad",
    "the movie is amazing"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(documents)

print(vectorizer.get_feature_names_out())
print(X.toarray())
# Out:
# ['amazing' 'bad' 'good' 'is' 'movie' 'the']
# [[0.         0.         0.69903033 0.41285857 0.41285857 0.41285857]
#  [0.         0.69903033 0.         0.41285857 0.41285857 0.41285857]
#  [0.69903033 0.         0.         0.41285857 0.41285857 0.41285857]]
