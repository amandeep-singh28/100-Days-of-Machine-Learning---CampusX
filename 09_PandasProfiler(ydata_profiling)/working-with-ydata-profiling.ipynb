# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv(r'E:\100 Days of Machine Learning - CampusX\09_PandasProfiler(ydata_profiling)\train.csv')

# %%
profile = ProfileReport(df)
profile.to_file(output_file = 'output.html')
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 298.08it/s]<00:00, 31.29it/s, Describe variable: Embarked]
# Summarize dataset: 100%|██████████| 47/47 [00:05<00:00,  8.73it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:05<00:00,  5.79s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.37it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 65.42it/s]
